# %% [markdown]
# # 03 — Feature Engineering
#
# Metryki pochodne pod KPI i dashboard.
#
# **TODO:**
# - ADR, margin %, discount_rate, is_cancelled
# - sezon, kubełki długości pobytu
# - Margin Leakage Rate, Revenue at Risk (baza pod what-if depozytu)
